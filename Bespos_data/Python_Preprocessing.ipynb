# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
from datetime import datetime, timedelta

# %%
product_data= pd.read_csv('Dataset/PRODUCT_data.csv')
product_batch_data= pd.read_csv('Dataset/PRODUCT_BATCH_data.csv')
transaction_data= pd.read_csv('Dataset/TRANSACTION_data.csv')
# transaction_product_data_1= pd.read_csv('TRANSACTION_PRODUCT_1.csv')
# transaction_product_data_2= pd.read_csv('TRANSACTION_PRODUCT_2.csv')
# transaction_data_combined= pd.read_csv('TRANSACTION_DATA_combined.csv')
# transaction_product_combined=pd.read_csv('transaction_product_combined.csv')
transaction_product_data_1a=pd.read_csv('Dataset/transaction_product_data_1a.csv')

# %%
transaction_data['customer_id'] = np.random.randint(1, 4000, len(transaction_data))

# %%
transaction_data = transaction_data[transaction_data['net_amount'] > 0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 transaction_data = transaction_data[transaction_data['net_amount'] > 0]
#
# NameError: name 'transaction_data' is not defined

# %%
# Add random expiry_date to product_batch_data

# Generate random expiry dates within a range
start_date = datetime.today()
end_date = start_date + timedelta(days=365)

# Add a new column for expiry_date
product_batch_data['expiry_date'] = [random.uniform(start_date, end_date) for _ in range(len(product_batch_data))]

# %%
product_data.drop(columns=[col for col in product_data.columns if col not in ['id','unit_id','name','product_type_id','product_measurement_unit_id','product_manufacture_id','product_brand_id','product_rack_id','is_expiry','default_discount_percentage','max_discount_percentage','is_stock_data','is_consumable','is_nil_stock','sales_price','expiry_days']], inplace=True)

product_batch_data.drop(columns=[col for col in product_batch_data.columns if col not in ['id','unit_id','store_outlet_id','product_id','transaction_id','supplier_id','purchase_type_id','counter_id','batch_num','mrp','purchase_price','purchase_rate','sales_price','purchase_discount_percentage','sales_discount_percentage','units_per_pack','opening_stock','current_stock','expiry_date']], inplace=True)

# %%
# prompt: split transaction_product_combined into 6 dataset

transaction_product_data_1a = transaction_product_combined[:100000]
transaction_product_data_2a = transaction_product_combined[100000:200000]
transaction_product_data_3a = transaction_product_combined[200000:300000]
transaction_product_data_4a = transaction_product_combined[300000:400000]
transaction_product_data_5a = transaction_product_combined[400000:500000]
transaction_product_data_6a = transaction_product_combined[500000:600000]

# %%
transaction_product_data_1a['Store_outlet_id']=0
for i in range(100000):
    if transaction_product_data_1a['transaction_id'][i] in transaction_data_combined['id']:
        transaction_product_data_1a['Store_outlet_id'][i] = transaction_data_combined[transaction_data_combined['id'] == transaction_product_data_1a['transaction_id'][i]]['store_outlet_id'].iloc[0]

transaction_product_data_2a['Store_outlet_id']=0
for i in range(100000,200000):
    if transaction_product_data_2a['transaction_id'][i] in transaction_data_combined['id']:
        transaction_product_data_2a['Store_outlet_id'][i] = transaction_data_combined[transaction_data_combined['id'] == transaction_product_data_2a['transaction_id'][i]]['store_outlet_id'].iloc[0]
        
transaction_product_data_3a['Store_outlet_id']=0
for i in range(200000,300000):
    if transaction_product_data_3a['transaction_id'][i] in transaction_data_combined['id']:
        transaction_product_data_3a['Store_outlet_id'][i] = transaction_data_combined[transaction_data_combined['id'] == transaction_product_data_3a['transaction_id'][i]]['store_outlet_id'].iloc[0]

transaction_product_data_5a['Store_outlet_id']=0
for i in range(400000,500000):
    if transaction_product_data_5a['transaction_id'][i] in transaction_data_combined['id']:
        transaction_product_data_5a['Store_outlet_id'][i] = transaction_data_combined[transaction_data_combined['id'] == transaction_product_data_5a['transaction_id'][i]]['store_outlet_id'].iloc[0]
        
transaction_product_data_6a['Store_outlet_id']=0
for i in range(500000,600000):
    if transaction_product_data_6a['transaction_id'][i] in transaction_data_combined['id']:
        transaction_product_data_6a['Store_outlet_id'][i] = transaction_data_combined[transaction_data_combined['id'] == transaction_product_data_6a['transaction_id'][i]]['store_outlet_id'].iloc[0]
# Out:
# C:\Users\bhara\AppData\Local\Temp\ipykernel_14640\843467997.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   transaction_product_data_1a['Store_outlet_id']=0
# C:\Users\bhara\AppData\Local\Temp\ipykernel_14640\843467997.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   transaction_product_data_1a['Store_outlet_id'][i] = transaction_data_combined[transaction_data_combined['id'] == transaction_product_data_1a['transaction_id'][i]]['store_outlet_id'].iloc[0]
# ...

# %%
transaction_product_data_1a['customer_id']=0
for i in range(100000):
    if transaction_product_data_1a['transaction_id'][i] in transaction_data['id']:
        transaction_product_data_1a['customer_id'][i] = transaction_data[transaction_data['id'] == transaction_product_data_1a['transaction_id'][i]]['customer_id'].iloc[0]
      
transaction_product_data_2a['customer_id']=0
for i in range(100000,200000):
    if transaction_product_data_2a['transaction_id'][i] in transaction_data['id']:
        transaction_product_data_2a['customer_id'][i] = transaction_data[transaction_data['id'] == transaction_product_data_2a['transaction_id'][i]]['customer_id'].iloc[0]

transaction_product_data_3a['customer_id']=0
for i in range(200000,300000):
    if transaction_product_data_3a['transaction_id'][i] in transaction_data['id']:
        transaction_product_data_3a['customer_id'][i] = transaction_data[transaction_data['id'] == transaction_product_data_3a['transaction_id'][i]]['customer_id'].iloc[0]

transaction_product_data_5a['customer_id']=0
for i in range(400000,500000):
    if transaction_product_data_5a['transaction_id'][i] in transaction_data['id']:
        transaction_product_data_5a['customer_id'][i] = transaction_data[transaction_data['id'] == transaction_product_data_5a['transaction_id'][i]]['customer_id'].iloc[0]
    
transaction_product_data_6a['customer_id']=0
for i in range(500000,600000):
    if transaction_product_data_6a['transaction_id'][i] in transaction_data['id']:
        transaction_product_data_6a['customer_id'][i] = transaction_data[transaction_data['id'] == transaction_product_data_6a['transaction_id'][i]]['customer_id'].iloc[0]
# Out:
# C:\Users\bhara\AppData\Local\Temp\ipykernel_14640\2159524921.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   transaction_product_data_1a['customer_id']=0
# C:\Users\bhara\AppData\Local\Temp\ipykernel_14640\2159524921.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   transaction_product_data_1a['customer_id'][i] = transaction_data[transaction_data['id'] == transaction_product_data_1a['transaction_id'][i]]['customer_id'].iloc[0]
# C:\Users\bhara\AppData\Local\Temp\ipykernel_14640\2159524921.py:6: SettingWithCopyWarning:
# ...

# %%
transaction_product_data_1a['transaction_date']=0
for i in range(100000):
    if transaction_product_data_1a['transaction_id'][i] in transaction_data_combined['id']:
        transaction_product_data_1a['transaction_date'][i] = transaction_data_combined[transaction_data_combined['id'] == transaction_product_data_1a['transaction_id'][i]]['transaction_date'].iloc[0]

transaction_product_data_2a['transaction_date']=0
for i in range(100000,20000):
    if transaction_product_data_2a['transaction_id'][i] in transaction_data_combined['id']:
        transaction_product_data_2a['transaction_date'][i] = transaction_data_combined[transaction_data_combined['id'] == transaction_product_data_2a['transaction_id'][i]]['transaction_date'].iloc[0]

transaction_product_data_3a['transaction_date']=0
for i in range(100000):
    if transaction_product_data_3a['transaction_id'][i] in transaction_data_combined['id']:
        transaction_product_data_3a['transaction_date'][i] = transaction_data_combined[transaction_data_combined['id'] == transaction_product_data_3a['transaction_id'][i]]['transaction_date'].iloc[0]
        
transaction_product_data_5a['transaction_date']=0
for i in range(100000):
    if transaction_product_data_5a['transaction_id'][i] in transaction_data_combined['id']:
        transaction_product_data_5a['transaction_date'][i] = transaction_data_combined[transaction_data_combined['id'] == transaction_product_data_5a['transaction_id'][i]]['transaction_date'].iloc[0]

transaction_product_data_6a['transaction_date']=0
for i in range(100000):
    if transaction_product_data_6a['transaction_id'][i] in transaction_data_combined['id']:
        transaction_product_data_6a['transaction_date'][i] = transaction_data_combined[transaction_data_combined['id'] == transaction_product_data_6a['transaction_id'][i]]['transaction_date'].iloc[0]

# %%
transaction_product_data_7a = transaction_product_combined[600000:700000]
transaction_product_data_8a = transaction_product_combined[700000:800000]
transaction_product_data_9a = transaction_product_combined[800000:900000]
transaction_product_data_10a = transaction_product_combined[900000:1000000]
transaction_product_data_11a = transaction_product_combined[1000000:]

# %%
transaction_product_data_7a['Store_outlet_id']=0
for i in range(600000,700000):
    if transaction_product_data_7a['transaction_id'][i] in transaction_data_combined['id']:
        transaction_product_data_7a['Store_outlet_id'][i] = transaction_data_combined[transaction_data_combined['id'] == transaction_product_data_7a['transaction_id'][i]]['store_outlet_id'].iloc[0]

transaction_product_data_8a['Store_outlet_id']=0
for i in range(700000,800000):
    if transaction_product_data_8a['transaction_id'][i] in transaction_data_combined['id']:
        transaction_product_data_8a['Store_outlet_id'][i] = transaction_data_combined[transaction_data_combined['id'] == transaction_product_data_8a['transaction_id'][i]]['store_outlet_id'].iloc[0]
# Out:
# C:\Users\bhara\AppData\Local\Temp\ipykernel_7872\228960047.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   transaction_product_data_7a['Store_outlet_id']=0
# C:\Users\bhara\AppData\Local\Temp\ipykernel_7872\228960047.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   transaction_product_data_7a['Store_outlet_id'][i] = transaction_data_combined[transaction_data_combined['id'] == transaction_product_data_7a['transaction_id'][i]]['store_outlet_id'].iloc[0]
# ...

# %%
transaction_product_data_9a['Store_outlet_id']=0
for i in range(800000,900000):
    if transaction_product_data_9a['transaction_id'][i] in transaction_data_combined['id']:
        transaction_product_data_9a['Store_outlet_id'][i] = transaction_data_combined[transaction_data_combined['id'] == transaction_product_data_9a['transaction_id'][i]]['store_outlet_id'].iloc[0]

transaction_product_data_10a['Store_outlet_id']=0
for i in range(900000,1000000):
    if transaction_product_data_10a['transaction_id'][i] in transaction_data_combined['id']:
        transaction_product_data_10a['Store_outlet_id'][i] = transaction_data_combined[transaction_data_combined['id'] == transaction_product_data_10a['transaction_id'][i]]['store_outlet_id'].iloc[0]
        
transaction_product_data_11a['Store_outlet_id']=0
for i in range(1000000,len(transaction_data_combined)):
    if transaction_product_data_11a['transaction_id'][i] in transaction_data_combined['id']:
        transaction_product_data_11a['Store_outlet_id'][i] = transaction_data_combined[transaction_data_combined['id'] == transaction_product_data_11a['transaction_id'][i]]['store_outlet_id'].iloc[0]
# Out:
# C:\Users\bhara\AppData\Local\Temp\ipykernel_7872\3855760277.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   transaction_product_data_9a['Store_outlet_id']=0
# C:\Users\bhara\AppData\Local\Temp\ipykernel_7872\3855760277.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   transaction_product_data_9a['Store_outlet_id'][i] = transaction_data_combined[transaction_data_combined['id'] == transaction_product_data_9a['transaction_id'][i]]['store_outlet_id'].iloc[0]
# ...

# %%
transaction_product_data_7a['customer_id']=0
for i in range(600000,700000):
    if transaction_product_data_7a['transaction_id'][i] in transaction_data['transaction_id']:
        transaction_product_data_7a['customer_id'][i] = transaction_data[transaction_data['transaction_id'] == transaction_product_data_7a['transaction_id'][i]]['customer_id'].iloc[0]

transaction_product_data_8a['customer_id']=0
for i in range(700000,800000):
    if transaction_product_data_8a['transaction_id'][i] in transaction_data['transaction_id']:
        transaction_product_data_8a['customer_id'][i] = transaction_data[transaction_data['transaction_id'] == transaction_product_data_8a['transaction_id'][i]]['customer_id'].iloc[0]
# Out:
# C:\Users\bhara\AppData\Local\Temp\ipykernel_7872\3638898721.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   transaction_product_data_7a['customer_id']=0
# C:\Users\bhara\AppData\Local\Temp\ipykernel_7872\3638898721.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   transaction_product_data_7a['customer_id'][i] = transaction_data[transaction_data['transaction_id'] == transaction_product_data_7a['transaction_id'][i]]['customer_id'].iloc[0]
# C:\Users\bhara\AppData\Local\Temp\ipykernel_7872\3638898721.py:6: SettingWithCopyWarning:
# ...

# %%
transaction_product_data_9a['customer_id']=0
for i in range(800000,900000):
    if transaction_product_data_9a['transaction_id'][i] in transaction_data['transaction_id']:
        transaction_product_data_9a['customer_id'][i] = transaction_data[transaction_data['transaction_id'] == transaction_product_data_9a['transaction_id'][i]]['customer_id'].iloc[0]

transaction_product_data_10a['customer_id']=0
for i in range(900000,1000000):
    if transaction_product_data_10a['transaction_id'][i] in transaction_data['transaction_id']:
        transaction_product_data_10a['customer_id'][i] = transaction_data[transaction_data['transaction_id'] == transaction_product_data_10a['transaction_id'][i]]['customer_id'].iloc[0]
        
transaction_product_data_11a['customer_id']=0
for i in range(1000000,len(transaction_data_combined)):
    if transaction_product_data_11a['transaction_id'][i] in transaction_data['transaction_id']:
        transaction_product_data_11a['customer_id'][i] = transaction_data[transaction_data['transaction_id'] == transaction_product_data_11a['transaction_id'][i]]['customer_id'].iloc[0]
# Out:
# C:\Users\bhara\AppData\Local\Temp\ipykernel_7872\619623575.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   transaction_product_data_9a['customer_id']=0
# C:\Users\bhara\AppData\Local\Temp\ipykernel_7872\619623575.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   transaction_product_data_9a['customer_id'][i] = transaction_data[transaction_data['transaction_id'] == transaction_product_data_9a['transaction_id'][i]]['customer_id'].iloc[0]
# C:\Users\bhara\AppData\Local\Temp\ipykernel_7872\619623575.py:6: SettingWithCopyWarning:
# ...

# %%
transaction_product_data_7a['transaction_date']=0
for i in range(600000,700000):
    if transaction_product_data_7a['transaction_id'][i] in transaction_data_combined['id']:
        transaction_product_data_7a['transaction_date'][i] = transaction_data_combined[transaction_data_combined['id'] == transaction_product_data_7a['transaction_id'][i]]['transaction_date'].iloc[0]

transaction_product_data_8a['transaction_date']=0
for i in range(700000,80000):
    if transaction_product_data_8a['transaction_id'][i] in transaction_data_combined['id']:
        transaction_product_data_8a['transaction_date'][i] = transaction_data_combined[transaction_data_combined['id'] == transaction_product_data_8a['transaction_id'][i]]['transaction_date'].iloc[0]

transaction_product_data_9a['transaction_date']=0
for i in range(800000,900000):
    if transaction_product_data_9a['transaction_id'][i] in transaction_data_combined['id']:
        transaction_product_data_9a['transaction_date'][i] = transaction_data_combined[transaction_data_combined['id'] == transaction_product_data_9a['transaction_id'][i]]['transaction_date'].iloc[0]
        
transaction_product_data_10a['transaction_date']=0
for i in range(900000,1000000):
    if transaction_product_data_10a['transaction_id'][i] in transaction_data_combined['id']:
        transaction_product_data_10a['transaction_date'][i] = transaction_data_combined[transaction_data_combined['id'] == transaction_product_data_10a['transaction_id'][i]]['transaction_date'].iloc[0]

transaction_product_data_11a['transaction_date']=0
for i in range(1000000,len(transaction_data_combined)):
    if transaction_product_data_11a['transaction_id'][i] in transaction_data_combined['id']:
        transaction_product_data_11a['transaction_date'][i] = transaction_data_combined[transaction_data_combined['id'] == transaction_product_data_11a['transaction_id'][i]]['transaction_date'].iloc[0]
# Out:
# C:\Users\bhara\AppData\Local\Temp\ipykernel_7872\967761652.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   transaction_product_data_7a['transaction_date']=0
# C:\Users\bhara\AppData\Local\Temp\ipykernel_7872\967761652.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   transaction_product_data_7a['transaction_date'][i] = transaction_data_combined[transaction_data_combined['id'] == transaction_product_data_7a['transaction_id'][i]]['transaction_date'].iloc[0]
# ...

# %%
transaction_product_data_7a.to_csv('transaction_product_data_7a.csv', index=False)
transaction_product_data_8a.to_csv('transaction_product_data_8a.csv', index=False)
transaction_product_data_9a.to_csv('transaction_product_data_9a.csv', index=False)
transaction_product_data_10a.to_csv('transaction_product_data_10a.csv', index=False)
transaction_product_data_11a.to_csv('transaction_product_data_11a.csv', index=False)

# %%
transaction_product_combined_1a_11a = pd.concat([transaction_product_data_1a, transaction_product_data_2a,transaction_product_data_3a,transaction_product_data_5a,transaction_product_data_6a,transaction_product_data_7a,transaction_product_data_8a,transaction_product_data_9a,transaction_product_data_10a,transaction_product_data_11a], ignore_index=True)
transaction_product_combined_1a_11a.to_csv('transaction_product_combined_1a_11a.csv', index=False)

# %%
transaction_product_data_1a.to_csv('transaction_product_data_1a.csv', index=False)
transaction_product_data_2a.to_csv('transaction_product_data_2a.csv', index=False)
transaction_product_data_3a.to_csv('transaction_product_data_3a.csv', index=False)
transaction_product_data_5a.to_csv('transaction_product_data_5a.csv', index=False)
transaction_product_data_6a.to_csv('transaction_product_data_6a.csv', index=False)
transaction_data.to_csv('transaction_data.csv', index=False)

# %%
transaction_product_combined_1a_6a = pd.concat([transaction_product_data_1a, transaction_product_data_2a,transaction_product_data_3a,transaction_product_data_5a,transaction_product_data_6a], ignore_index=True)
transaction_product_combined_1a_6a.to_csv('transaction_product_combined_1a_6a.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 transaction_product_combined_1a_6a = pd.concat([transaction_product_data_1a, transaction_product_data_2a,transaction_product_data_3a,transaction_product_data_5a,transaction_product_data_6a], ignore_index=True)
#       2 transaction_product_combined_1a_6a.to_csv('transaction_product_combined_1a_6a.csv', index=False)
#
# NameError: name 'transaction_product_data_1a' is not defined

# %%
# prompt: drop rows with qty=0

transaction_product_combined = transaction_product_combined[transaction_product_combined["qty"] > 10]

# %%
#  sort product_batch_data in desending order of sales price

product_batch_data.sort_values(by="sales_price", ascending=False, inplace=True)

# %%
product_batch_data=product_batch_data[product_batch_data['sales_price'] <= 2.250000e+05	]

# %%
product_batch_data['profit']=0
profit=0
for i in range(85526):
    if product_batch_data['id'][i] in list(transaction_product_combined['product_batch_id']):
        qty_sum=transaction_product_combined[transaction_product_combined['product_batch_id']==product_batch_data['id'][i]]['qty'].sum()
        if product_batch_data['sales_price'][i]==0:
            profit=0
        else:
            profit=(product_batch_data['sales_price'][i]-product_batch_data['purchase_rate'][i])*qty_sum
    product_batch_data['profit'][i]=profit
# Out:
# C:\Users\bhara\AppData\Local\Temp\ipykernel_17432\385711544.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   product_batch_data['profit'][i]=profit

# %%
product_batch_data['profit']=0
profit=0
for i in range(85528,200000):
    if product_batch_data['id'][i] in list(transaction_product_combined['product_batch_id']):
        qty_sum=transaction_product_combined[transaction_product_combined['product_batch_id']==product_batch_data['id'][i]]['qty'].sum()
        if product_batch_data['sales_price'][i]==0:
            profit=0
        else:
            profit=(product_batch_data['sales_price'][i]-product_batch_data['purchase_rate'][i])*qty_sum
    product_batch_data['profit'][i]=profit
# Out:
# C:\Users\bhara\AppData\Local\Temp\ipykernel_17432\535438325.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   product_batch_data['profit'][i]=profit

# %%
product_batch_data['profit']=0
profit=0
c=0
for i in range(200000,300000):
    if product_batch_data['id'][i] in list(transaction_product_combined['product_batch_id']):
        qty_sum=transaction_product_combined[transaction_product_combined['product_batch_id']==product_batch_data['id'][i]]['qty'].sum()
        if product_batch_data['sales_price'][i]==0:
            profit=0
            c+=1
        else:
            profit=(product_batch_data['sales_price'][i]-product_batch_data['purchase_rate'][i])*qty_sum
    product_batch_data['profit'][i]=profit
print(c)
# Out:
# C:\Users\bhara\AppData\Local\Temp\ipykernel_17432\908358325.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   product_batch_data['profit'][i]=profit

# %%
product_batch_data['profit']=0
profit=0
for i in range(300000,324713):
    if product_batch_data['id'][i] in list(transaction_product_combined['product_batch_id']):
        qty_sum=transaction_product_combined[transaction_product_combined['product_batch_id']==product_batch_data['id'][i]]['qty'].sum()
        if product_batch_data['sales_price'][i]==0:
            profit=0
        else:
            profit=(product_batch_data['sales_price'][i]-product_batch_data['purchase_rate'][i])*qty_sum
    product_batch_data['profit'][i]=profit
# Out:
# C:\Users\bhara\AppData\Local\Temp\ipykernel_17432\3246620111.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   product_batch_data['profit'][i]=profit

# %%
product_batch_data['profit']=0
profit=0
c=0
for i in range(324714,400000):
    if product_batch_data['id'][i] in list(transaction_product_combined['product_batch_id']):
        qty_sum=transaction_product_combined[transaction_product_combined['product_batch_id']==product_batch_data['id'][i]]['qty'].sum()
        if product_batch_data['sales_price'][i]==0:
            profit=0
            c+=1
        else:
            profit=(product_batch_data['sales_price'][i]-product_batch_data['purchase_rate'][i])*qty_sum
    product_batch_data['profit'][i]=profit
print(c)
# Out:
# C:\Users\bhara\AppData\Local\Temp\ipykernel_12736\2395900219.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   product_batch_data['profit'][i]=profit
# 0

# %%
profit=0
c=0
for i in range(500000,550000):
    if product_batch_data['id'][i] in list(transaction_product_combined['product_batch_id']):
        qty_sum=transaction_product_combined[transaction_product_combined['product_batch_id']==product_batch_data['id'][i]]['qty'].sum()
        if product_batch_data['sales_price'][i]==0:
            profit=0
            c+=1
        else:
            profit=(product_batch_data['sales_price'][i]-product_batch_data['purchase_rate'][i])*qty_sum
    product_batch_data['profit'][i]=profit
print(c)
# Out:
# C:\Users\bhara\AppData\Local\Temp\ipykernel_18984\608072623.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   product_batch_data['profit'][i]=profit
# 0

# %%
product_batch_data.to_csv('product_batch_data.csv', index=False)

# %%
profit=0
c=0
for i in range(550000,600000):
    if product_batch_data['id'][i] in list(transaction_product_combined['product_batch_id']):
        qty_sum=transaction_product_combined[transaction_product_combined['product_batch_id']==product_batch_data['id'][i]]['qty'].sum()
        if product_batch_data['sales_price'][i]==0:
            profit=0
            c+=1
        else:
            profit=(product_batch_data['sales_price'][i]-product_batch_data['purchase_rate'][i])*qty_sum
    product_batch_data['profit'][i]=profit
print(c)
# Out:
# C:\Users\bhara\AppData\Local\Temp\ipykernel_18984\46006012.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   product_batch_data['profit'][i]=profit
# 0

# %%
product_batch_data.head()
# Out:
#        id  unit_id  store_outlet_id  product_id  transaction_id  supplier_id  \
# 0  441291       18               14      152158        718364.0      21995.0
# 1  441292       18               18      152158        733660.0      21995.0
# 2  411712       69               91      135679             NaN      21874.0
# 3  411716       69               91      135679             NaN      21874.0
# 4  433619       18               18      150281        733656.0      21995.0
#
#    purchase_type_id  counter_id  batch_num       mrp  purchase_price  \
# 0                11          21       1390  250000.0       158629.38
# 1                11          21       1390  250000.0       158629.38
# 2                61          80       2020  177800.0        17775.04
# 3                61          80       2080  170360.0        17775.04
# 4                11          21       1030  147000.0        96738.02
#
#    purchase_rate  sales_price  purchase_discount_percentage  \
# ...

# %%
len(product_batch_data[product_batch_data['profit']!=0])
# Out:
# 198841

# %%
product_batch_data['profit'].unique()
# Out:
# array([  0.     , 876.     , 169.38   , ...,  50.61186, 440.22   ,
#        163.242  ])

# %%
len(product_batch_data)
# Out:
# 1064490

# %%
product_batch_data['id'][324715]
# Out:
# 4770

# %%
product_batch_data= pd.read_csv('PRODUCT_BATCH_data.csv')
transaction_product_combined=pd.read_csv('transaction_product_combined.csv')

# %%
product_batch_data= pd.read_csv('PRODUCT_BATCH_data.csv')
transaction_product_data_1a=pd.read_csv('transaction_product_data_1a.csv')

# %%
product_data= pd.read_csv('PRODUCT.csv')

# %%
# Calculate profit for each transaction
transaction_product_data_1a['profit'] = (transaction_product_data_1a['sales_price'] - transaction_product_data_1a['rate']) * transaction_product_data_1a['qty']

# %%
transaction_product_data_1a.head()
# Out:
#    index       id  transaction_id  product_id  product_batch_id   qty   rate  \
# 0      0  2600234          749599       43796            413609  30.0  28.00
# 1      2  2600236          749600       63767            243213   1.2  45.00
# 2      3  2600237          749600       63915            216407   2.0  23.93
# 3     10  2600244          749600       64308            343703   2.0  45.00
# 4     12  2600246          749600       64644            322825   6.7  24.00
#
#    mrp_rate  sales_price  cgst_amount  sgst_amount  amount  total_amount  \
# 0      39.0        28.00         0.00         0.00  840.00        840.00
# 1      45.0        45.00         0.00         0.00   54.00         54.00
# 2      30.0        28.24         4.31         4.31   47.86         56.48
# 3      45.0        45.00         0.00         0.00   90.00         90.00
# 4      24.0        24.00         0.00         0.00  160.80        160.80
#
#    cost  Store_outlet_id  customer_id transaction_date  profit
# ...

# %%
# prompt: top 5 most profitable products by store


# # Read the transaction data
# transaction_data = pd.read_csv('transaction_data.csv')

# # Read the product data
# product_data = pd.read_csv('product_data.csv')

# Merge the transaction and product data
merged_data = pd.merge(transaction_product_data_1a, product_batch_data, on='product_id')

# Calculate the profit for each product in each store
product_profit = merged_data.groupby(['Store_outlet_id', 'product_id'])['profit_y'].sum()

# Get the top 5 most profitable products for each store
top_5_products_by_store = product_profit.groupby('Store_outlet_id').nlargest(5)

# Print the top 5 most profitable products for each store
print("Top 5 Most Profitable Products by Store:")
for store_id, products in top_5_products_by_store.groupby('Store_outlet_id'):
    print(f"\nStore ID: {store_id}")
    for product_id, profit in products.items():
        # product_name = product_data[product_data['id'] == product_id]['name'].values[0]
        print(f"- Product Id: {product_id[2]}, Profit: {profit:.2f}")
# Out:
# Top 5 Most Profitable Products by Store:
#
# Store ID: 2
# - Product Id: 269, Profit: 5169731.09
# - Product Id: 137, Profit: 1124412.03
# - Product Id: 60, Profit: 1105029.94
# - Product Id: 19630, Profit: 933677.22
# - Product Id: 19635, Profit: 716402.10
#
# Store ID: 4
# - Product Id: 3479, Profit: 574242.60
# - Product Id: 925, Profit: 466189.62
# - Product Id: 2934, Profit: 405242.18
# - Product Id: 2057, Profit: 352001.40
# - Product Id: 25041, Profit: 133072.50
#
# Store ID: 6
# - Product Id: 6693, Profit: 72007.39
# - Product Id: 56008, Profit: 2430.00
# - Product Id: 7314, Profit: 0.00
#
# Store ID: 9
# - Product Id: 8513, Profit: 0.00
#
# Store ID: 11
# - Product Id: 154214, Profit: 69909.04
# - Product Id: 1775, Profit: 56564.80
# - Product Id: 3135, Profit: 34723.51
# - Product Id: 2089, Profit: 27453.79
# - Product Id: 2862, Profit: 26996.42
#
# Store ID: 13
# - Product Id: 3843, Profit: 65953445.92
# - Product Id: 3798, Profit: 8523921.88
# ...

# %%
merged_data.head()
# Out:
#    index     id_x  transaction_id_x  product_id  product_batch_id   qty  rate  \
# 0      0  2600234            749599       43796            413609  30.0  28.0
# 1      0  2600234            749599       43796            413609  30.0  28.0
# 2      0  2600234            749599       43796            413609  30.0  28.0
# 3      0  2600234            749599       43796            413609  30.0  28.0
# 4      0  2600234            749599       43796            413609  30.0  28.0
#
#    mrp_rate  sales_price_x  cgst_amount  ...  purchase_price  purchase_rate  \
# 0      39.0           28.0          0.0  ...            28.0           28.0
# 1      39.0           28.0          0.0  ...            28.0           28.0
# 2      39.0           28.0          0.0  ...            28.0           28.0
# 3      39.0           28.0          0.0  ...            28.0           28.0
# 4      39.0           28.0          0.0  ...            27.0           27.0
#
# ...
